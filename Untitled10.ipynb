# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiRndo/Top-100-Docker-Labs-Linux/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s1 = "This"

print(s1[1:])

print(len(s1))

print("Length of string is " + str(len(s1)))

print(s1.upper())

print(s1.lower())
# Out:
# his
# 4
# Length of string is 4
# THIS
# this
