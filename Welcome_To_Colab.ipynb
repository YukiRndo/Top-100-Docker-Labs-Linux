# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiRndo/Top-100-Docker-Labs-Linux/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import DataFrame

cars = {
'make': ['Ford', 'Honda', 'Toyota', 'Tesla'],
'model': ['Taurus', 'Accord', 'Camry', 'Model S'],
'MSRP': [27595, 23570, 23495, 68000]
}

carData = DataFrame(cars)

carData

print('carData.index = ', carData.index)

print('carData.columns = ', carData.columns)

carData2 = DataFrame(cars, index = [1,2,3,4])

carData2['year'] = 2018

carData2['dealership'] = [
'Courtesy Ford',
'Capital Honda',
'Spartan Toyota',
'North Tesla'
]

carData2
# Out:
# carData.index =  RangeIndex(start=0, stop=4, step=1)
# carData.columns =  Index(['make', 'model', 'MSRP'], dtype='object')
#      make    model   MSRP  year      dealership
# 1    Ford   Taurus  27595  2018   Courtesy Ford
# 2   Honda   Accord  23570  2018   Capital Honda
# 3  Toyota    Camry  23495  2018  Spartan Toyota
# 4   Tesla  Model S  68000  2018     North Tesla
