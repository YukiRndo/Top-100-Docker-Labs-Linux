# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiRndo/Top-100-Docker-Labs-Linux/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import Series
import numpy as np

s2 = Series(np.random.randn(6))

print('Series s2 =\n', s2, '\n')

print('s2.values = ', s2.values)

print('s2.index = ', s2.index)

print('s2.dtype = ', s2.dtype)
# Out:
# Series s2 =
#  0   -0.492214
# 1   -1.423778
# 2    0.111120
# 3   -0.534039
# 4   -0.772221
# 5   -0.562569
# dtype: float64
#
# s2.values =  [-0.49221388 -1.42377834  0.11111996 -0.53403922 -0.77222107 -0.5625689 ]
# s2.index =  RangeIndex(start=0, stop=6, step=1)
# s2.dtype =  float64
